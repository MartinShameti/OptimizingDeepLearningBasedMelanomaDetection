# %%
import os
import json
import time
import random
import warnings
from pathlib import Path
from datetime import datetime

import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt

from PIL import Image, UnidentifiedImageError

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    cohen_kappa_score, roc_auc_score, confusion_matrix,
    roc_curve, precision_recall_curve, auc
)

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input

warnings.filterwarnings("ignore")

print("TensorFlow:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow: 2.19.0
# GPUs: []

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

ROOT = Path.cwd()
PROJECT_ROOT = ROOT / "19042026"

E00_ROOT = PROJECT_ROOT / "E00_hyperparameter_tuning"
E02_ROOT = PROJECT_ROOT / "E02_class_imbalance"
EXP_ROOT = PROJECT_ROOT / "E03_augmentation_overfitting"

IMG_SIZE = (224, 224)
THRESHOLD = 0.50
BATCH_EXTRACT = 16

USE_HAIR_REMOVAL = True
USE_SEGMENTATION = True   # keep best E01 variant setting

# 3 meaningful augmentation settings only
RUNS = [
    {
        "run_name": "E03_aug_mild",
        "aug_mode": "mild",
        "use_aug": True
    },
    {
        "run_name": "E03_aug_moderate",
        "aug_mode": "moderate",
        "use_aug": True
    },
    {
        "run_name": "E03_aug_strong",
        "aug_mode": "strong",
        "use_aug": True
    }
]

print("PROJECT_ROOT:", PROJECT_ROOT)
print("E00_ROOT:", E00_ROOT)
print("E02_ROOT:", E02_ROOT)
print("EXP_ROOT:", EXP_ROOT)
# Out:
# PROJECT_ROOT: C:\Users\User\Desktop\Melanoma Detection Based on Deep Neural Networks Draft 01042026\19042026
# E00_ROOT: C:\Users\User\Desktop\Melanoma Detection Based on Deep Neural Networks Draft 01042026\19042026\E00_hyperparameter_tuning
# E02_ROOT: C:\Users\User\Desktop\Melanoma Detection Based on Deep Neural Networks Draft 01042026\19042026\E02_class_imbalance
# EXP_ROOT: C:\Users\User\Desktop\Melanoma Detection Based on Deep Neural Networks Draft 01042026\19042026\E03_augmentation_overfitting

# %%
SUBDIRS = [
    "configs",
    "models",
    "histories",
    "metrics",
    "predictions",
    "plots",
    "confusion_matrices",
    "feature_cache",
    "logs",
    "summary",
    "preprocessing_samples"
]

for sub in SUBDIRS:
    (EXP_ROOT / sub).mkdir(parents=True, exist_ok=True)

for run in RUNS:
    run_name = run["run_name"]
    for sub in ["models", "histories", "metrics", "predictions", "plots", "confusion_matrices", "feature_cache"]:
        (EXP_ROOT / sub / run_name).mkdir(parents=True, exist_ok=True)

print("Folders ready.")
# Out:
# Folders ready.

# %%
def save_json(obj, path):
    with open(path, "w", encoding="utf-8") as f:
        json.dump(obj, f, indent=4)

def load_json(path):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

def verify_image(file_path):
    try:
        with Image.open(file_path) as img:
            img.verify()
        return True
    except (UnidentifiedImageError, OSError, IOError):
        return False

def remove_hairs_bgr(img_bgr):
    gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (17, 17))
    blackhat = cv2.morphologyEx(gray, cv2.MORPH_BLACKHAT, kernel)
    _, mask = cv2.threshold(blackhat, 10, 255, cv2.THRESH_BINARY)
    cleaned = cv2.inpaint(img_bgr, mask, 1, cv2.INPAINT_TELEA)
    return cleaned, mask

def simple_segment_lesion(img_bgr):
    gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (5, 5), 0)
    _, thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if len(contours) == 0:
        return img_bgr, thresh

    largest = max(contours, key=cv2.contourArea)
    mask = np.zeros_like(gray)
    cv2.drawContours(mask, [largest], -1, 255, thickness=-1)

    segmented = cv2.bitwise_and(img_bgr, img_bgr, mask=mask)

    x, y, w, h = cv2.boundingRect(largest)
    crop = segmented[y:y+h, x:x+w] if w > 0 and h > 0 else segmented
    return crop, mask

def apply_augmentation(img_rgb, mode="mild"):
    h, w = img_rgb.shape[:2]

    if mode == "mild":
        if random.random() < 0.5:
            img_rgb = cv2.flip(img_rgb, 1)
        angle = random.uniform(-10, 10)
        scale = random.uniform(0.95, 1.05)
        tx = random.uniform(-0.03*w, 0.03*w)
        ty = random.uniform(-0.03*h, 0.03*h)
        alpha = random.uniform(0.95, 1.05)
        beta = random.uniform(-8, 8)

    elif mode == "moderate":
        if random.random() < 0.5:
            img_rgb = cv2.flip(img_rgb, 1)
        angle = random.uniform(-20, 20)
        scale = random.uniform(0.90, 1.10)
        tx = random.uniform(-0.05*w, 0.05*w)
        ty = random.uniform(-0.05*h, 0.05*h)
        alpha = random.uniform(0.90, 1.10)
        beta = random.uniform(-15, 15)

    else:  # strong
        if random.random() < 0.5:
            img_rgb = cv2.flip(img_rgb, 1)
        angle = random.uniform(-30, 30)
        scale = random.uniform(0.85, 1.15)
        tx = random.uniform(-0.08*w, 0.08*w)
        ty = random.uniform(-0.08*h, 0.08*h)
        alpha = random.uniform(0.85, 1.15)
        beta = random.uniform(-20, 20)

    M = cv2.getRotationMatrix2D((w//2, h//2), angle, scale)
    M[:, 2] += [tx, ty]
    img_rgb = cv2.warpAffine(img_rgb, M, (w, h), borderMode=cv2.BORDER_REFLECT_101)

    img_rgb = cv2.convertScaleAbs(img_rgb, alpha=alpha, beta=beta)
    return img_rgb

def preprocess_image_for_resnet(path, img_size=(224, 224), use_hair_removal=True, use_segmentation=True, use_aug=False, aug_mode="mild"):
    img_bgr = cv2.imread(str(path))
    if img_bgr is None:
        raise ValueError(f"Could not read image: {path}")

    original = img_bgr.copy()
    hair_mask = None
    seg_mask = None

    if use_hair_removal:
        img_bgr, hair_mask = remove_hairs_bgr(img_bgr)

    if use_segmentation:
        img_bgr, seg_mask = simple_segment_lesion(img_bgr)

    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    img_rgb = cv2.resize(img_rgb, img_size, interpolation=cv2.INTER_AREA)

    if use_aug:
        img_rgb = apply_augmentation(img_rgb, mode=aug_mode)

    img_arr = np.asarray(img_rgb, dtype=np.float32)
    img_arr = preprocess_input(img_arr)

    return img_arr, original, hair_mask, seg_mask

def evaluate_binary(y_true, y_prob, threshold=0.5):
    y_pred = (y_prob >= threshold).astype(int)

    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, zero_division=0)
    rec = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    kappa = cohen_kappa_score(y_true, y_pred)

    try:
        roc = roc_auc_score(y_true, y_prob)
    except:
        roc = np.nan

    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()

    return {
        "accuracy": float(acc),
        "precision": float(prec),
        "recall": float(rec),
        "f1": float(f1),
        "kappa": float(kappa),
        "roc_auc": float(roc) if not np.isnan(roc) else None,
        "tn": int(tn),
        "fp": int(fp),
        "fn": int(fn),
        "tp": int(tp),
        "threshold": float(threshold)
    }

def plot_confusion(cm, title, save_path):
    fig, ax = plt.subplots(figsize=(5, 4))
    labels = ["Non-Melanoma", "Melanoma"]
    ax.imshow(cm, cmap="Blues")
    ax.set_xticks(range(2))
    ax.set_yticks(range(2))
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
    ax.set_xlabel("Predicted")
    ax.set_ylabel("True")
    ax.set_title(title)
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, cm[i, j], ha="center", va="center", color="black")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.close()

def plot_history(history, save_dir, run_name):
    hist = pd.DataFrame(history.history)

    plt.figure(figsize=(7, 5))
    plt.plot(hist["accuracy"], label="Train Accuracy")
    plt.plot(hist["val_accuracy"], label="Val Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title(f"Accuracy - {run_name}")
    plt.legend()
    plt.tight_layout()
    plt.savefig(save_dir / f"{run_name}_accuracy.png", dpi=300, bbox_inches="tight")
    plt.close()

    plt.figure(figsize=(7, 5))
    plt.plot(hist["loss"], label="Train Loss")
    plt.plot(hist["val_loss"], label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"Loss - {run_name}")
    plt.legend()
    plt.tight_layout()
    plt.savefig(save_dir / f"{run_name}_loss.png", dpi=300, bbox_inches="tight")
    plt.close()

def plot_roc_pr(y_true, y_prob, save_dir, run_name):
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(6, 5))
    plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
    plt.plot([0, 1], [0, 1], linestyle="--")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"ROC - {run_name}")
    plt.legend()
    plt.tight_layout()
    plt.savefig(save_dir / f"{run_name}_roc.png", dpi=300, bbox_inches="tight")
    plt.close()

    precision, recall, _ = precision_recall_curve(y_true, y_prob)
    pr_auc = auc(recall, precision)

    plt.figure(figsize=(6, 5))
    plt.plot(recall, precision, label=f"AUC = {pr_auc:.4f}")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.title(f"PR Curve - {run_name}")
    plt.legend()
    plt.tight_layout()
    plt.savefig(save_dir / f"{run_name}_pr.png", dpi=300, bbox_inches="tight")
    plt.close()

# %%
best_cfg = load_json(E00_ROOT / "summary" / "best_config.json")
best_hparams = best_cfg["best_config"]

best_e02 = load_json(E02_ROOT / "summary" / "best_E02_variant.json")

train_df = pd.read_csv(E00_ROOT / "summary" / "train_split.csv")
val_df   = pd.read_csv(E00_ROOT / "summary" / "val_split.csv")
test_df  = pd.read_csv(E00_ROOT / "summary" / "test_split.csv")

train_df["image_path"] = train_df["image_path"].apply(Path)
val_df["image_path"] = val_df["image_path"].apply(Path)
test_df["image_path"] = test_df["image_path"].apply(Path)

print("Best E00 config:")
print(json.dumps(best_cfg, indent=4))

print("\nBest E02 variant:")
print(json.dumps(best_e02, indent=4))

print("\nTrain:", train_df.shape)
print("Val:", val_df.shape)
print("Test:", test_df.shape)
# Out:
# Best E00 config:
# {
#     "best_by": "f1",
#     "sort_column": "test_f1",
#     "best_run_name": "run_004_du256_do04_lr5e-05_bs16",
#     "best_config": {
#         "dense_units": 256,
#         "dropout": 0.4,
#         "lr": 5e-05,
#         "batch_size": 16,
#         "epochs": 15
#     },
#     "best_test_metrics": {
#         "accuracy": 0.982874617737003,
#         "precision": 0.75,
#         "recall": 0.05172413793103448,
#         "f1": 0.0967741935483871,
#         "kappa": 0.0947022879629813,
#         "roc_auc": 0.8362176321552798,
#         "tn": 3211,
#         "fp": 1,
#         "fn": 55,
#         "tp": 3
#     }
# }
#
# Best E02 variant:
# {
#     "run_name": "E02_class_balanced_bce",
#     "mode": "class_balanced_bce",
#     "source_e01_run": "E01b_baseline_segmented",
#     "accuracy": 0.9596330275229358,
#     "precision": 0.12244897959183673,
#     "recall": 0.20689655172413793,
#     "f1": 0.15384615384615385,
#     "kappa": 0.1345598614140896,
#     "roc_auc": 0.8305707046850174,
#     "tn": 3126,
#     "fp": 86,
#     "fn": 46,
#     "tp": 12,
#     "runtime_sec": 170.56
# }
#
# Train: (26154, 5)
# Val: (3269, 5)
# Test: (3270, 5)

# %%
manifest_e02 = load_json(E02_ROOT / "summary" / "experiment_manifest.json")
cb_class_weights = manifest_e02["class_balanced_weights"]

print("Using class-balanced weights from E02:")
print(cb_class_weights)
# Out:
# Using class-balanced weights from E02:
# {'0': 0.09379925454519228, '1': 1.9062007454548076}

# %%
sample_df = train_df.sample(min(6, len(train_df)), random_state=SEED)

for run in RUNS:
    run_name = run["run_name"]
    aug_mode = run["aug_mode"]

    out_dir = EXP_ROOT / "preprocessing_samples" / run_name
    out_dir.mkdir(parents=True, exist_ok=True)

    for idx, row in sample_df.iterrows():
        img_arr, original_bgr, hair_mask, seg_mask = preprocess_image_for_resnet(
            row["image_path"],
            img_size=IMG_SIZE,
            use_hair_removal=USE_HAIR_REMOVAL,
            use_segmentation=USE_SEGMENTATION,
            use_aug=True,
            aug_mode=aug_mode
        )

        fig, axes = plt.subplots(1, 3, figsize=(12, 4))

        axes[0].imshow(cv2.cvtColor(original_bgr, cv2.COLOR_BGR2RGB))
        axes[0].set_title("Original")
        axes[0].axis("off")

        axes[1].imshow(hair_mask, cmap="gray")
        axes[1].set_title("Hair Mask")
        axes[1].axis("off")

        axes[2].imshow(seg_mask, cmap="gray")
        axes[2].set_title("Segmentation Mask")
        axes[2].axis("off")

        plt.tight_layout()
        plt.savefig(out_dir / f"sample_{idx}.png", dpi=300, bbox_inches="tight")
        plt.close()

# %%
base_model = ResNet50(
    weights="imagenet",
    include_top=False,
    pooling="avg",
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
)
base_model.trainable = False

print("Frozen ResNet50 feature extractor ready.")
print("Output feature dim:", base_model.output_shape[-1])
# Out:
# Frozen ResNet50 feature extractor ready.
# Output feature dim: 2048

# %%
def extract_features(df_split, split_name, run_name, use_aug=False, aug_mode="mild"):
    cache_dir = EXP_ROOT / "feature_cache" / run_name
    cache_dir.mkdir(parents=True, exist_ok=True)

    cache_x = cache_dir / f"X_{split_name}.npy"
    cache_y = cache_dir / f"y_{split_name}.npy"

    if cache_x.exists() and cache_y.exists():
        print(f"[CACHE] {run_name} -> {split_name}")
        return np.load(cache_x), np.load(cache_y)

    print(f"[EXTRACT] {run_name} -> {split_name}")

    feature_batches = []
    label_batches = []

    batch_images = []
    batch_labels = []

    for i, (_, row) in enumerate(df_split.iterrows(), start=1):
        img_arr, _, _, _ = preprocess_image_for_resnet(
            row["image_path"],
            img_size=IMG_SIZE,
            use_hair_removal=USE_HAIR_REMOVAL,
            use_segmentation=USE_SEGMENTATION,
            use_aug=use_aug,
            aug_mode=aug_mode
        )

        batch_images.append(img_arr)
        batch_labels.append(row["target"])

        if len(batch_images) == BATCH_EXTRACT:
            batch_images_np = np.array(batch_images, dtype=np.float32)
            batch_features = base_model.predict(batch_images_np, batch_size=BATCH_EXTRACT, verbose=0)

            feature_batches.append(batch_features)
            label_batches.append(np.array(batch_labels, dtype=np.int32))

            batch_images = []
            batch_labels = []

            if i % (BATCH_EXTRACT * 50) == 0:
                print(f"Processed {i}/{len(df_split)} images for {run_name} - {split_name}")

    if len(batch_images) > 0:
        batch_images_np = np.array(batch_images, dtype=np.float32)
        batch_features = base_model.predict(batch_images_np, batch_size=BATCH_EXTRACT, verbose=0)

        feature_batches.append(batch_features)
        label_batches.append(np.array(batch_labels, dtype=np.int32))

    X = np.concatenate(feature_batches, axis=0)
    y = np.concatenate(label_batches, axis=0)

    np.save(cache_x, X)
    np.save(cache_y, y)

    return X, y

# %%
def build_head_model(feature_dim, dense_units, dropout, lr):
    model = keras.Sequential([
        layers.Input(shape=(feature_dim,)),
        layers.Dense(dense_units, activation="relu"),
        layers.Dropout(dropout),
        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model

# %%
all_results = []

for run in RUNS:
    run_name = run["run_name"]
    aug_mode = run["aug_mode"]

    print("\n" + "=" * 90)
    print("Running:", run_name)
    print("Augmentation mode:", aug_mode)

    run_start = time.time()

    # train gets augmentation
    X_train, y_train = extract_features(train_df, "train", run_name, use_aug=True, aug_mode=aug_mode)

    # val/test stay clean
    X_val, y_val = extract_features(val_df, "val", run_name, use_aug=False, aug_mode=aug_mode)
    X_test, y_test = extract_features(test_df, "test", run_name, use_aug=False, aug_mode=aug_mode)

    model = build_head_model(
        feature_dim=X_train.shape[1],
        dense_units=best_hparams["dense_units"],
        dropout=best_hparams["dropout"],
        lr=best_hparams["lr"]
    )

    callbacks = [
        keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=4,
            restore_best_weights=True,
            verbose=1
        )
    ]

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=best_hparams["epochs"],
        batch_size=best_hparams["batch_size"],
        verbose=1,
        callbacks=callbacks,
        class_weight={int(k): float(v) for k, v in cb_class_weights.items()}
    )

    runtime_sec = time.time() - run_start

    model.save(EXP_ROOT / "models" / run_name / f"{run_name}.keras")

    hist_df = pd.DataFrame(history.history)
    hist_df.to_csv(EXP_ROOT / "histories" / run_name / f"{run_name}_history.csv", index=False)
    plot_history(history, EXP_ROOT / "plots" / run_name, run_name)

    y_val_prob = model.predict(X_val, batch_size=best_hparams["batch_size"], verbose=0).ravel()
    y_test_prob = model.predict(X_test, batch_size=best_hparams["batch_size"], verbose=0).ravel()

    val_metrics = evaluate_binary(y_val, y_val_prob, threshold=THRESHOLD)
    test_metrics = evaluate_binary(y_test, y_test_prob, threshold=THRESHOLD)

    pred_df = pd.DataFrame({
        "image_name": test_df["image_name"].values,
        "true_label": y_test,
        "pred_prob": y_test_prob,
        "pred_label": (y_test_prob >= THRESHOLD).astype(int)
    })
    pred_df.to_csv(EXP_ROOT / "predictions" / run_name / f"{run_name}_test_predictions.csv", index=False)

    metrics_package = {
        "run_name": run_name,
        "aug_mode": aug_mode,
        "source_e02_run": best_e02["run_name"],
        "best_hyperparameters_from_E00": best_hparams,
        "val_metrics": val_metrics,
        "test_metrics": test_metrics,
        "runtime_sec": round(runtime_sec, 2)
    }
    save_json(metrics_package, EXP_ROOT / "metrics" / run_name / f"{run_name}_metrics.json")

    cm = confusion_matrix(y_test, (y_test_prob >= THRESHOLD).astype(int), labels=[0, 1])
    plot_confusion(
        cm,
        title=f"Confusion Matrix - {run_name}",
        save_path=EXP_ROOT / "confusion_matrices" / run_name / f"{run_name}_cm.png"
    )

    plot_roc_pr(y_test, y_test_prob, EXP_ROOT / "plots" / run_name, run_name)

    row = {
        "run_name": run_name,
        "aug_mode": aug_mode,
        "source_e02_run": best_e02["run_name"],
        "accuracy": test_metrics["accuracy"],
        "precision": test_metrics["precision"],
        "recall": test_metrics["recall"],
        "f1": test_metrics["f1"],
        "kappa": test_metrics["kappa"],
        "roc_auc": test_metrics["roc_auc"],
        "tn": test_metrics["tn"],
        "fp": test_metrics["fp"],
        "fn": test_metrics["fn"],
        "tp": test_metrics["tp"],
        "runtime_sec": round(runtime_sec, 2)
    }
    all_results.append(row)

results_df = pd.DataFrame(all_results)
results_df.to_csv(EXP_ROOT / "summary" / "E03_results_comparison.csv", index=False)
results_df
# Out:
# ==========================================================================================
# Running: E03_aug_mild
# Augmentation mode: mild
# [EXTRACT] E03_aug_mild -> train
# Processed 800/26154 images for E03_aug_mild - train
# Processed 1600/26154 images for E03_aug_mild - train
# Processed 2400/26154 images for E03_aug_mild - train
# Processed 3200/26154 images for E03_aug_mild - train
# Processed 4000/26154 images for E03_aug_mild - train
# Processed 4800/26154 images for E03_aug_mild - train
# Processed 5600/26154 images for E03_aug_mild - train
# Processed 6400/26154 images for E03_aug_mild - train
# Processed 7200/26154 images for E03_aug_mild - train
# Processed 8000/26154 images for E03_aug_mild - train
# Processed 8800/26154 images for E03_aug_mild - train
# Processed 9600/26154 images for E03_aug_mild - train
# Processed 10400/26154 images for E03_aug_mild - train
# Processed 11200/26154 images for E03_aug_mild - train
# Processed 12000/26154 images for E03_aug_mild - train
# Processed 12800/26154 images for E03_aug_mild - train
# Processed 13600/26154 images for E03_aug_mild - train
# Processed 14400/26154 images for E03_aug_mild - train
# Processed 15200/26154 images for E03_aug_mild - train
# Processed 16000/26154 images for E03_aug_mild - train
# Processed 16800/26154 images for E03_aug_mild - train
# Processed 17600/26154 images for E03_aug_mild - train
# Processed 18400/26154 images for E03_aug_mild - train
# Processed 19200/26154 images for E03_aug_mild - train
# Processed 20000/26154 images for E03_aug_mild - train
# Processed 20800/26154 images for E03_aug_mild - train
# Processed 21600/26154 images for E03_aug_mild - train
# Processed 22400/26154 images for E03_aug_mild - train
# Processed 23200/26154 images for E03_aug_mild - train
# Processed 24000/26154 images for E03_aug_mild - train
# Processed 24800/26154 images for E03_aug_mild - train
# Processed 25600/26154 images for E03_aug_mild - train
# [EXTRACT] E03_aug_mild -> val
# Processed 800/3269 images for E03_aug_mild - val
# Processed 1600/3269 images for E03_aug_mild - val
# Processed 2400/3269 images for E03_aug_mild - val
# Processed 3200/3269 images for E03_aug_mild - val
# [EXTRACT] E03_aug_mild -> test
# Processed 800/3270 images for E03_aug_mild - test
# Processed 1600/3270 images for E03_aug_mild - test
# Processed 2400/3270 images for E03_aug_mild - test
# Processed 3200/3270 images for E03_aug_mild - test
# Epoch 1/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8754 - loss: 0.0768 - val_accuracy: 0.9532 - val_loss: 0.1891
# Epoch 2/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8914 - loss: 0.0573 - val_accuracy: 0.9559 - val_loss: 0.1738
# Epoch 3/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.8967 - loss: 0.0558 - val_accuracy: 0.9575 - val_loss: 0.1699
# Epoch 4/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9014 - loss: 0.0522 - val_accuracy: 0.9474 - val_loss: 0.1688
# Epoch 5/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9026 - loss: 0.0489 - val_accuracy: 0.9462 - val_loss: 0.1758
# Epoch 6/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9049 - loss: 0.0473 - val_accuracy: 0.9520 - val_loss: 0.1613
# Epoch 7/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9084 - loss: 0.0455 - val_accuracy: 0.9480 - val_loss: 0.1574
# Epoch 8/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9071 - loss: 0.0430 - val_accuracy: 0.9547 - val_loss: 0.1465
# Epoch 9/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9111 - loss: 0.0416 - val_accuracy: 0.9517 - val_loss: 0.1497
# Epoch 10/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9189 - loss: 0.0399 - val_accuracy: 0.9584 - val_loss: 0.1332
# Epoch 11/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9229 - loss: 0.0384 - val_accuracy: 0.9559 - val_loss: 0.1409
# Epoch 12/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9243 - loss: 0.0360 - val_accuracy: 0.9578 - val_loss: 0.1333
# Epoch 13/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9260 - loss: 0.0357 - val_accuracy: 0.9544 - val_loss: 0.1449
# Epoch 14/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9310 - loss: 0.0328 - val_accuracy: 0.9615 - val_loss: 0.1267
# Epoch 15/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9261 - loss: 0.0330 - val_accuracy: 0.9559 - val_loss: 0.1330
# Restoring model weights from the end of the best epoch: 14.
#
# ==========================================================================================
# Running: E03_aug_moderate
# Augmentation mode: moderate
# [EXTRACT] E03_aug_moderate -> train
# Processed 800/26154 images for E03_aug_moderate - train
# Processed 1600/26154 images for E03_aug_moderate - train
# Processed 2400/26154 images for E03_aug_moderate - train
# Processed 3200/26154 images for E03_aug_moderate - train
# Processed 4000/26154 images for E03_aug_moderate - train
# Processed 4800/26154 images for E03_aug_moderate - train
# Processed 5600/26154 images for E03_aug_moderate - train
# Processed 6400/26154 images for E03_aug_moderate - train
# Processed 7200/26154 images for E03_aug_moderate - train
# Processed 8000/26154 images for E03_aug_moderate - train
# Processed 8800/26154 images for E03_aug_moderate - train
# Processed 9600/26154 images for E03_aug_moderate - train
# Processed 10400/26154 images for E03_aug_moderate - train
# Processed 11200/26154 images for E03_aug_moderate - train
# Processed 12000/26154 images for E03_aug_moderate - train
# Processed 12800/26154 images for E03_aug_moderate - train
# Processed 13600/26154 images for E03_aug_moderate - train
# Processed 14400/26154 images for E03_aug_moderate - train
# Processed 15200/26154 images for E03_aug_moderate - train
# Processed 16000/26154 images for E03_aug_moderate - train
# Processed 16800/26154 images for E03_aug_moderate - train
# Processed 17600/26154 images for E03_aug_moderate - train
# Processed 18400/26154 images for E03_aug_moderate - train
# Processed 19200/26154 images for E03_aug_moderate - train
# Processed 20000/26154 images for E03_aug_moderate - train
# Processed 20800/26154 images for E03_aug_moderate - train
# Processed 21600/26154 images for E03_aug_moderate - train
# Processed 22400/26154 images for E03_aug_moderate - train
# Processed 23200/26154 images for E03_aug_moderate - train
# Processed 24000/26154 images for E03_aug_moderate - train
# Processed 24800/26154 images for E03_aug_moderate - train
# Processed 25600/26154 images for E03_aug_moderate - train
# [EXTRACT] E03_aug_moderate -> val
# Processed 800/3269 images for E03_aug_moderate - val
# Processed 1600/3269 images for E03_aug_moderate - val
# Processed 2400/3269 images for E03_aug_moderate - val
# Processed 3200/3269 images for E03_aug_moderate - val
# [EXTRACT] E03_aug_moderate -> test
# Processed 800/3270 images for E03_aug_moderate - test
# Processed 1600/3270 images for E03_aug_moderate - test
# Processed 2400/3270 images for E03_aug_moderate - test
# Processed 3200/3270 images for E03_aug_moderate - test
# Epoch 1/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8633 - loss: 0.0798 - val_accuracy: 0.9569 - val_loss: 0.1603
# Epoch 2/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8764 - loss: 0.0600 - val_accuracy: 0.9498 - val_loss: 0.1710
# Epoch 3/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8897 - loss: 0.0562 - val_accuracy: 0.9507 - val_loss: 0.1621
# Epoch 4/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8980 - loss: 0.0517 - val_accuracy: 0.9553 - val_loss: 0.1550
# Epoch 5/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9013 - loss: 0.0505 - val_accuracy: 0.9556 - val_loss: 0.1546
# Epoch 6/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9051 - loss: 0.0478 - val_accuracy: 0.9529 - val_loss: 0.1510
# Epoch 7/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9128 - loss: 0.0462 - val_accuracy: 0.9618 - val_loss: 0.1342
# Epoch 8/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9132 - loss: 0.0430 - val_accuracy: 0.9556 - val_loss: 0.1409
# Epoch 9/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9132 - loss: 0.0423 - val_accuracy: 0.9581 - val_loss: 0.1375
# Epoch 10/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9188 - loss: 0.0406 - val_accuracy: 0.9572 - val_loss: 0.1399
# Epoch 11/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9239 - loss: 0.0385 - val_accuracy: 0.9645 - val_loss: 0.1192
# Epoch 12/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9233 - loss: 0.0381 - val_accuracy: 0.9612 - val_loss: 0.1307
# Epoch 13/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9273 - loss: 0.0348 - val_accuracy: 0.9593 - val_loss: 0.1272
# Epoch 14/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9337 - loss: 0.0344 - val_accuracy: 0.9627 - val_loss: 0.1194
# Epoch 15/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9344 - loss: 0.0326 - val_accuracy: 0.9648 - val_loss: 0.1144
# Restoring model weights from the end of the best epoch: 15.
#
# ==========================================================================================
# Running: E03_aug_strong
# Augmentation mode: strong
# [EXTRACT] E03_aug_strong -> train
# Processed 800/26154 images for E03_aug_strong - train
# Processed 1600/26154 images for E03_aug_strong - train
# Processed 2400/26154 images for E03_aug_strong - train
# Processed 3200/26154 images for E03_aug_strong - train
# Processed 4000/26154 images for E03_aug_strong - train
# Processed 4800/26154 images for E03_aug_strong - train
# Processed 5600/26154 images for E03_aug_strong - train
# Processed 6400/26154 images for E03_aug_strong - train
# Processed 7200/26154 images for E03_aug_strong - train
# Processed 8000/26154 images for E03_aug_strong - train
# Processed 8800/26154 images for E03_aug_strong - train
# Processed 9600/26154 images for E03_aug_strong - train
# Processed 10400/26154 images for E03_aug_strong - train
# Processed 11200/26154 images for E03_aug_strong - train
# Processed 12000/26154 images for E03_aug_strong - train
# Processed 12800/26154 images for E03_aug_strong - train
# Processed 13600/26154 images for E03_aug_strong - train
# Processed 14400/26154 images for E03_aug_strong - train
# Processed 15200/26154 images for E03_aug_strong - train
# Processed 16000/26154 images for E03_aug_strong - train
# Processed 16800/26154 images for E03_aug_strong - train
# Processed 17600/26154 images for E03_aug_strong - train
# Processed 18400/26154 images for E03_aug_strong - train
# Processed 19200/26154 images for E03_aug_strong - train
# Processed 20000/26154 images for E03_aug_strong - train
# Processed 20800/26154 images for E03_aug_strong - train
# Processed 21600/26154 images for E03_aug_strong - train
# Processed 22400/26154 images for E03_aug_strong - train
# Processed 23200/26154 images for E03_aug_strong - train
# Processed 24000/26154 images for E03_aug_strong - train
# Processed 24800/26154 images for E03_aug_strong - train
# Processed 25600/26154 images for E03_aug_strong - train
# [EXTRACT] E03_aug_strong -> val
# Processed 800/3269 images for E03_aug_strong - val
# Processed 1600/3269 images for E03_aug_strong - val
# Processed 2400/3269 images for E03_aug_strong - val
# Processed 3200/3269 images for E03_aug_strong - val
# [EXTRACT] E03_aug_strong -> test
# Processed 800/3270 images for E03_aug_strong - test
# Processed 1600/3270 images for E03_aug_strong - test
# Processed 2400/3270 images for E03_aug_strong - test
# Processed 3200/3270 images for E03_aug_strong - test
# Epoch 1/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8599 - loss: 0.0828 - val_accuracy: 0.9581 - val_loss: 0.1726
# Epoch 2/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8847 - loss: 0.0591 - val_accuracy: 0.9593 - val_loss: 0.1666
# Epoch 3/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8996 - loss: 0.0543 - val_accuracy: 0.9587 - val_loss: 0.1655
# Epoch 4/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - accuracy: 0.8989 - loss: 0.0520 - val_accuracy: 0.9621 - val_loss: 0.1447
# Epoch 5/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8949 - loss: 0.0519 - val_accuracy: 0.9538 - val_loss: 0.1609
# Epoch 6/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9080 - loss: 0.0473 - val_accuracy: 0.9615 - val_loss: 0.1479
# Epoch 7/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9123 - loss: 0.0457 - val_accuracy: 0.9645 - val_loss: 0.1396
# Epoch 8/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9178 - loss: 0.0428 - val_accuracy: 0.9575 - val_loss: 0.1529
# Epoch 9/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9192 - loss: 0.0423 - val_accuracy: 0.9550 - val_loss: 0.1471
# Epoch 10/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9220 - loss: 0.0395 - val_accuracy: 0.9541 - val_loss: 0.1489
# Epoch 11/15
# 1635/1635 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9211 - loss: 0.0387 - val_accuracy: 0.9572 - val_loss: 0.1423
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 7.
#            run_name  aug_mode          source_e02_run  accuracy  precision  \
# 0      E03_aug_mild      mild  E02_class_balanced_bce  0.961468   0.113636
# 1  E03_aug_moderate  moderate  E02_class_balanced_bce  0.964526   0.108108
# 2    E03_aug_strong    strong  E02_class_balanced_bce  0.963914   0.142857
#
#      recall        f1     kappa   roc_auc    tn  fp  fn  tp  runtime_sec
# 0  0.172414  0.136986  0.118131  0.833459  3134  78  48  10     23775.30
# 1  0.137931  0.121212  0.103381  0.835788  3146  66  50   8     23420.31
# 2  0.206897  0.169014  0.151202  0.836446  3140  72  46  12     23039.34

# %%
results_sorted = results_df.sort_values(by=["f1", "recall", "kappa"], ascending=False).reset_index(drop=True)
best_e03 = results_sorted.iloc[0].to_dict()

save_json(best_e03, EXP_ROOT / "summary" / "best_E03_variant.json")

print("Best E03 variant:")
print(json.dumps(best_e03, indent=4))
# Out:
# Best E03 variant:
# {
#     "run_name": "E03_aug_strong",
#     "aug_mode": "strong",
#     "source_e02_run": "E02_class_balanced_bce",
#     "accuracy": 0.963914373088685,
#     "precision": 0.14285714285714285,
#     "recall": 0.20689655172413793,
#     "f1": 0.16901408450704225,
#     "kappa": 0.151202386294644,
#     "roc_auc": 0.8364457637308369,
#     "tn": 3140,
#     "fp": 72,
#     "fn": 46,
#     "tp": 12,
#     "runtime_sec": 23039.34
# }

# %%
if len(results_df) > 0:
    plot_cols = ["accuracy", "precision", "recall", "f1", "kappa", "roc_auc"]
    plot_df = results_df[["run_name"] + plot_cols].copy()

    x = np.arange(len(plot_df))
    width = 0.12

    plt.figure(figsize=(16, 6))
    for idx, col in enumerate(plot_cols):
        plt.bar(x + idx * width, plot_df[col].fillna(0), width=width, label=col)

    plt.xticks(x + width * (len(plot_cols)-1) / 2, plot_df["run_name"], rotation=45, ha="right")
    plt.ylabel("Score")
    plt.title("E03 Augmentation / Overfitting Comparison")
    plt.legend()
    plt.tight_layout()
    plt.savefig(EXP_ROOT / "plots" / "E03_metrics_comparison.png", dpi=300, bbox_inches="tight")
    plt.show()

# %%
manifest = {
    "experiment_id": "E03",
    "experiment_name": "Augmentation and Overfitting Control",
    "date_created": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
    "project_root": str(PROJECT_ROOT),
    "experiment_root": str(EXP_ROOT),
    "source_e02_run": best_e02["run_name"],
    "best_hyperparameters_from_E00": best_hparams,
    "threshold": THRESHOLD,
    "use_hair_removal": USE_HAIR_REMOVAL,
    "use_segmentation": USE_SEGMENTATION,
    "class_balanced_weights_from_E02": cb_class_weights,
    "runs": RUNS
}
save_json(manifest, EXP_ROOT / "summary" / "experiment_manifest.json")
print("E03 finished.")
# Out:
# E03 finished.
